# %% [markdown]
# <a href="https://colab.research.google.com/github/misrori/coding2023/blob/main/session10_to_share.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd



top50 = pd.read_csv('https://raw.githubusercontent.com/misrori/rdata/main/IMDB_50.csv',encoding='unicode_escape')
top200 = pd.read_csv('https://raw.githubusercontent.com/misrori/rdata/main/IMDB_top200.csv',encoding='unicode_escape')

# %%
top200.head().T
# Out:
#                                                                    0  \
# Unnamed: 0                                                         1
# Title                                       The Shawshank Redemption
# Year                                                            1994
# Rated                                                              R
# Released                                                 14 Oct 1994
# Runtime                                                      142 min
# Genre                                                   Crime, Drama
# Director                                              Frank Darabont
# Writer             Stephen King (short story "Rita Hayworth and S...
# Actors             Tim Robbins, Morgan Freeman, Bob Gunton, Willi...
# Plot               Two imprisoned men bond over a number of years...
# Language                                                     English
# Country                                                          USA
# Awards             Nominated for 7 Oscars. Another 19 wins & 30 n...
# Poster             https://images-na.ssl-images-amazon.com/images...
# Ratings.Source                               Internet Movie Database
# Ratings.Value                                                 9.3/10
# Metascore                                                       80.0
# imdbVotes                                                  1,825,626
# imdbID                                                     tt0111161
# Type                                                           movie
# tomatoMeter                                                      NaN
# tomatoImage                                                      NaN
# tomatoRating                                                     NaN
# tomatoReviews                                                    NaN
# tomatoFresh                                                      NaN
# tomatoRotten                                                     NaN
# tomatoConsensus                                                  NaN
# tomatoUserMeter                                                  NaN
# tomatoUserRating                                                 NaN
# tomatoUserReviews                                                NaN
# tomatoURL          http://www.rottentomatoes.com/m/shawshank_rede...
# DVD                                              1998-01-27 00:00:00
# BoxOffice                                                        NaN
# Production                                         Columbia Pictures
# Website                                                          NaN
# Response                                                        True
#
#                                                                    1  \
# Unnamed: 0                                                         2
# Title                                                  The Godfather
# Year                                                            1972
# Rated                                                              R
# Released                                                 24 Mar 1972
# Runtime                                                      175 min
# Genre                                                   Crime, Drama
# Director                                        Francis Ford Coppola
# Writer             Mario Puzo (screenplay), Francis Ford Coppola ...
# Actors             Marlon Brando, Al Pacino, James Caan, Richard ...
# Plot               The aging patriarch of an organized crime dyna...
# Language                                     English, Italian, Latin
# Country                                                          USA
# Awards               Won 3 Oscars. Another 23 wins & 27 nominations.
# Poster             https://images-na.ssl-images-amazon.com/images...
# Ratings.Source                               Internet Movie Database
# Ratings.Value                                                 9.2/10
# Metascore                                                      100.0
# imdbVotes                                                  1,243,444
# imdbID                                                     tt0068646
# Type                                                           movie
# tomatoMeter                                                      NaN
# tomatoImage                                                      NaN
# tomatoRating                                                     NaN
# tomatoReviews                                                    NaN
# tomatoFresh                                                      NaN
# tomatoRotten                                                     NaN
# tomatoConsensus                                                  NaN
# tomatoUserMeter                                                  NaN
# tomatoUserRating                                                 NaN
# tomatoUserReviews                                                NaN
# tomatoURL                 http://www.rottentomatoes.com/m/godfather/
# DVD                                              2001-10-09 00:00:00
# BoxOffice                                                        NaN
# Production                                        Paramount Pictures
# Website                                  http://www.thegodfather.com
# Response                                                        True
#
#                                                                    2  \
# Unnamed: 0                                                         3
# Title                                         The Godfather: Part II
# Year                                                            1974
# Rated                                                              R
# Released                                                 20 Dec 1974
# Runtime                                                      202 min
# Genre                                                   Crime, Drama
# Director                                        Francis Ford Coppola
# Writer             Francis Ford Coppola (screenplay), Mario Puzo ...
# Actors             Al Pacino, Robert Duvall, Diane Keaton, Robert...
# Plot               The early life and career of Vito Corleone in ...
# Language                  English, Italian, Spanish, Latin, Sicilian
# Country                                                          USA
# Awards               Won 6 Oscars. Another 10 wins & 20 nominations.
# Poster             https://images-na.ssl-images-amazon.com/images...
# Ratings.Source                               Internet Movie Database
# Ratings.Value                                                 9.0/10
# Metascore                                                       85.0
# imdbVotes                                                    856,870
# imdbID                                                     tt0071562
# Type                                                           movie
# tomatoMeter                                                      NaN
# tomatoImage                                                      NaN
# tomatoRating                                                     NaN
# tomatoReviews                                                    NaN
# tomatoFresh                                                      NaN
# tomatoRotten                                                     NaN
# tomatoConsensus                                                  NaN
# tomatoUserMeter                                                  NaN
# tomatoUserRating                                                 NaN
# tomatoUserReviews                                                NaN
# tomatoURL          http://www.rottentomatoes.com/m/godfather_part...
# DVD                                              2005-05-24 00:00:00
# BoxOffice                                                        NaN
# Production                                        Paramount Pictures
# Website                                 http://www.thegodfather.com/
# Response                                                        True
#
#                                                                    3  \
# Unnamed: 0                                                         4
# Title                                                The Dark Knight
# Year                                                            2008
# Rated                                                          PG-13
# Released                                                 18 Jul 2008
# Runtime                                                      152 min
# Genre                                           Action, Crime, Drama
# Director                                           Christopher Nolan
# Writer             Jonathan Nolan (screenplay), Christopher Nolan...
# Actors             Christian Bale, Heath Ledger, Aaron Eckhart, M...
# Plot               When the menace known as the Joker emerges fro...
# Language                                           English, Mandarin
# Country                                                      USA, UK
# Awards             Won 2 Oscars. Another 151 wins & 153 nominations.
# Poster             https://images-na.ssl-images-amazon.com/images...
# Ratings.Source                               Internet Movie Database
# Ratings.Value                                                 9.0/10
# Metascore                                                       82.0
# imdbVotes                                                  1,802,351
# imdbID                                                     tt0468569
# Type                                                           movie
# tomatoMeter                                                      NaN
# tomatoImage                                                      NaN
# tomatoRating                                                     NaN
# tomatoReviews                                                    NaN
# tomatoFresh                                                      NaN
# tomatoRotten                                                     NaN
# tomatoConsensus                                                  NaN
# tomatoUserMeter                                                  NaN
# tomatoUserRating                                                 NaN
# tomatoUserReviews                                                NaN
# tomatoURL           http://www.rottentomatoes.com/m/the_dark_knight/
# DVD                                              2008-12-09 00:00:00
# BoxOffice                                               $533,316,061
# Production                           Warner Bros. Pictures/Legendary
# Website                         http://thedarkknight.warnerbros.com/
# Response                                                        True
#
#                                                                    4
# Unnamed: 0                                                         5
# Title                                                   12 Angry Men
# Year                                                            1957
# Rated                                                       APPROVED
# Released                                                 01 Apr 1957
# Runtime                                                       96 min
# Genre                                                   Crime, Drama
# Director                                                Sidney Lumet
# Writer             Reginald Rose (story), Reginald Rose (screenplay)
# Actors             Martin Balsam, John Fiedler, Lee J. Cobb, E.G....
# Plot               A jury holdout attempts to prevent a miscarria...
# Language                                                     English
# Country                                                          USA
# Awards             Nominated for 3 Oscars. Another 16 wins & 8 no...
# Poster             https://images-na.ssl-images-amazon.com/images...
# Ratings.Source                               Internet Movie Database
# Ratings.Value                                                 8.9/10
# Metascore                                                       96.0
# imdbVotes                                                    494,215
# imdbID                                                     tt0050083
# Type                                                           movie
# tomatoMeter                                                      NaN
# tomatoImage                                                      NaN
# tomatoRating                                                     NaN
# tomatoReviews                                                    NaN
# tomatoFresh                                                      NaN
# tomatoRotten                                                     NaN
# tomatoConsensus                                                  NaN
# tomatoUserMeter                                                  NaN
# tomatoUserRating                                                 NaN
# tomatoUserReviews                                                NaN
# tomatoURL          http://www.rottentomatoes.com/m/1000013-12_ang...
# DVD                                              2001-03-06 00:00:00
# BoxOffice                                                        NaN
# Production                                      Criterion Collection
# Website            http://www.criterion.com/films/27871-12-angry-men
# Response                                                        True

# %% [markdown]
# # Combine the two data

# %%
df.dtypes
# Out:
# Unnamed: 0                    int64
# Title                        object
# Year                          int64
# Rated                        object
# Released                     object
# Runtime                      object
# Genre                        object
# Director                     object
# Writer                       object
# Actors                       object
# Plot                         object
# Language                     object
# Country                      object
# Awards                       object
# Poster                       object
# Ratings.Source               object
# Ratings.Value                object
# Metascore                   float64
# imdbVotes                    object
# imdbID                       object
# Type                         object
# tomatoMeter                 float64
# tomatoImage                 float64
# tomatoRating                float64
# tomatoReviews               float64
# tomatoFresh                 float64
# tomatoRotten                float64
# tomatoConsensus             float64
# tomatoUserMeter             float64
# tomatoUserRating            float64
# tomatoUserReviews           float64
# tomatoURL                    object
# DVD                  datetime64[ns]
# BoxOffice                    object
# Production                   object
# Website                      object
# Response                       bool
# dtype: object

# %% [markdown]
# ## Drop unnecessary columns
#
# Delete the followings:
#
# * everything with *tomato*
# * Poster
# * Website
# * Response
# * imdbID

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'Title', 'Year', 'Rated', 'Released', 'Runtime', 'Genre',
#        'Director', 'Writer', 'Actors', 'Plot', 'Language', 'Country', 'Awards',
#        'Ratings.Source', 'Ratings.Value', 'Metascore', 'imdbVotes', 'Type',
#        'DVD', 'BoxOffice', 'Production'],
#       dtype='object')

# %% [markdown]
# ## Deal with column names
#
# Rename some columns
#
# * **Unnamed: 0** to **IMDB_rank**
# * **Runtime** to **Lengt_min**
#
# Make sure all names are lower case and are separeted by _ in case needed.

# %%
df.columns
# Out:
# Index(['imdb_rank', 'title', 'year', 'rated', 'released', 'lengt_min', 'genre',
#        'director', 'writer', 'actors', 'plot', 'language', 'country', 'awards',
#        'ratings_source', 'ratings_value', 'metascore', 'imdbvotes', 'type',
#        'dvd', 'boxoffice', 'production'],
#       dtype='object')

# %% [markdown]
# ## Change data types
#
# `relesed` and `dvd` should be dates
#
# https://datagy.io/python-string-to-date/

# %% [markdown]
# The `IMDB rank` should be string.

# %% [markdown]
# ## `metascore`, `imdb_votes` and `box office` should be numeric.

# %%
df.head().T
# Out:
#                                                                 0  \
# imdb_rank                                                       1
# title                                    The Shawshank Redemption
# year                                                         1994
# rated                                                           R
# released                                      1994-10-14 00:00:00
# lengt_min                                                 142 min
# genre                                                Crime, Drama
# director                                           Frank Darabont
# writer          Stephen King (short story "Rita Hayworth and S...
# actors          Tim Robbins, Morgan Freeman, Bob Gunton, Willi...
# plot            Two imprisoned men bond over a number of years...
# language                                                  English
# country                                                       USA
# awards          Nominated for 7 Oscars. Another 19 wins & 30 n...
# ratings_source                            Internet Movie Database
# ratings_value                                              9.3/10
# metascore                                                    80.0
# imdbvotes                                                 1825626
# type                                                        movie
# dvd                                           1998-01-27 00:00:00
# boxoffice                                                     NaN
# production                                      Columbia Pictures
#
#                                                                 1  \
# imdb_rank                                                       2
# title                                               The Godfather
# year                                                         1972
# rated                                                           R
# released                                      1972-03-24 00:00:00
# lengt_min                                                 175 min
# genre                                                Crime, Drama
# director                                     Francis Ford Coppola
# writer          Mario Puzo (screenplay), Francis Ford Coppola ...
# actors          Marlon Brando, Al Pacino, James Caan, Richard ...
# plot            The aging patriarch of an organized crime dyna...
# language                                  English, Italian, Latin
# country                                                       USA
# awards            Won 3 Oscars. Another 23 wins & 27 nominations.
# ratings_source                            Internet Movie Database
# ratings_value                                              9.2/10
# metascore                                                   100.0
# imdbvotes                                                 1243444
# type                                                        movie
# dvd                                           2001-10-09 00:00:00
# boxoffice                                                     NaN
# production                                     Paramount Pictures
#
#                                                                 2  \
# imdb_rank                                                       3
# title                                      The Godfather: Part II
# year                                                         1974
# rated                                                           R
# released                                      1974-12-20 00:00:00
# lengt_min                                                 202 min
# genre                                                Crime, Drama
# director                                     Francis Ford Coppola
# writer          Francis Ford Coppola (screenplay), Mario Puzo ...
# actors          Al Pacino, Robert Duvall, Diane Keaton, Robert...
# plot            The early life and career of Vito Corleone in ...
# language               English, Italian, Spanish, Latin, Sicilian
# country                                                       USA
# awards            Won 6 Oscars. Another 10 wins & 20 nominations.
# ratings_source                            Internet Movie Database
# ratings_value                                              9.0/10
# metascore                                                    85.0
# imdbvotes                                                  856870
# type                                                        movie
# dvd                                           2005-05-24 00:00:00
# boxoffice                                                     NaN
# production                                     Paramount Pictures
#
#                                                                 3  \
# imdb_rank                                                       4
# title                                             The Dark Knight
# year                                                         2008
# rated                                                       PG-13
# released                                      2008-07-18 00:00:00
# lengt_min                                                 152 min
# genre                                        Action, Crime, Drama
# director                                        Christopher Nolan
# writer          Jonathan Nolan (screenplay), Christopher Nolan...
# actors          Christian Bale, Heath Ledger, Aaron Eckhart, M...
# plot            When the menace known as the Joker emerges fro...
# language                                        English, Mandarin
# country                                                   USA, UK
# awards          Won 2 Oscars. Another 151 wins & 153 nominations.
# ratings_source                            Internet Movie Database
# ratings_value                                              9.0/10
# metascore                                                    82.0
# imdbvotes                                                 1802351
# type                                                        movie
# dvd                                           2008-12-09 00:00:00
# boxoffice                                             533316061.0
# production                        Warner Bros. Pictures/Legendary
#
#                                                                 4
# imdb_rank                                                       5
# title                                                12 Angry Men
# year                                                         1957
# rated                                                    APPROVED
# released                                      1957-04-01 00:00:00
# lengt_min                                                  96 min
# genre                                                Crime, Drama
# director                                             Sidney Lumet
# writer          Reginald Rose (story), Reginald Rose (screenplay)
# actors          Martin Balsam, John Fiedler, Lee J. Cobb, E.G....
# plot            A jury holdout attempts to prevent a miscarria...
# language                                                  English
# country                                                       USA
# awards          Nominated for 3 Oscars. Another 16 wins & 8 no...
# ratings_source                            Internet Movie Database
# ratings_value                                              8.9/10
# metascore                                                    96.0
# imdbvotes                                                  494215
# type                                                        movie
# dvd                                           2001-03-06 00:00:00
# boxoffice                                                     NaN
# production                                   Criterion Collection

# %%
df.dtypes
# Out:
# imdb_rank                 object
# title                     object
# year                       int64
# rated                     object
# released          datetime64[ns]
# lengt_min                 object
# genre                     object
# director                  object
# writer                    object
# actors                    object
# plot                      object
# language                  object
# country                   object
# awards                    object
# ratings_source            object
# ratings_value             object
# metascore                float64
# imdbvotes                  int64
# type                      object
# dvd               datetime64[ns]
# boxoffice                float64
# production                object
# dtype: object

# %% [markdown]
# ## Create a month and day column. It should be int. The missing date should be january 1

# %%
df['month'].value_counts()
# Out:
# 12    34
# 1     25
# 6     24
# 10    23
# 9     23
# 11    21
# 7     20
# 2     19
# 8     19
# 3     16
# 5     14
# 4     12
# Name: month, dtype: int64

# %% [markdown]
# ## `length_min`
#
# This should be numeric, without the *min* word.

# %% [markdown]
# ### `genre`
#
# There are 1, 2 or 3 genre given for a film, to be able to deal with this we need them in different columns. Also pay attention to extra white spaces!

# %%
df.head().T
# Out:
#                                                                 0  \
# imdb_rank                                                       1
# title                                    The Shawshank Redemption
# year                                                         1994
# rated                                                           R
# released                                      1994-10-14 00:00:00
# lengt_min                                                     142
# genre                                                Crime, Drama
# director                                           Frank Darabont
# writer          Stephen King (short story "Rita Hayworth and S...
# actors          Tim Robbins, Morgan Freeman, Bob Gunton, Willi...
# plot            Two imprisoned men bond over a number of years...
# language                                                  English
# country                                                       USA
# awards          Nominated for 7 Oscars. Another 19 wins & 30 n...
# ratings_source                            Internet Movie Database
# ratings_value                                              9.3/10
# metascore                                                    80.0
# imdbvotes                                                 1825626
# type                                                        movie
# dvd                                           1998-01-27 00:00:00
# boxoffice                                                     NaN
# production                                      Columbia Pictures
# month                                                          10
# day                                                            14
# genre_1                                                     Crime
# genre_2                                                     Drama
# genre_3                                                      None
#
#                                                                 1  \
# imdb_rank                                                       2
# title                                               The Godfather
# year                                                         1972
# rated                                                           R
# released                                      1972-03-24 00:00:00
# lengt_min                                                     175
# genre                                                Crime, Drama
# director                                     Francis Ford Coppola
# writer          Mario Puzo (screenplay), Francis Ford Coppola ...
# actors          Marlon Brando, Al Pacino, James Caan, Richard ...
# plot            The aging patriarch of an organized crime dyna...
# language                                  English, Italian, Latin
# country                                                       USA
# awards            Won 3 Oscars. Another 23 wins & 27 nominations.
# ratings_source                            Internet Movie Database
# ratings_value                                              9.2/10
# metascore                                                   100.0
# imdbvotes                                                 1243444
# type                                                        movie
# dvd                                           2001-10-09 00:00:00
# boxoffice                                                     NaN
# production                                     Paramount Pictures
# month                                                           3
# day                                                            24
# genre_1                                                     Crime
# genre_2                                                     Drama
# genre_3                                                      None
#
#                                                                 2  \
# imdb_rank                                                       3
# title                                      The Godfather: Part II
# year                                                         1974
# rated                                                           R
# released                                      1974-12-20 00:00:00
# lengt_min                                                     202
# genre                                                Crime, Drama
# director                                     Francis Ford Coppola
# writer          Francis Ford Coppola (screenplay), Mario Puzo ...
# actors          Al Pacino, Robert Duvall, Diane Keaton, Robert...
# plot            The early life and career of Vito Corleone in ...
# language               English, Italian, Spanish, Latin, Sicilian
# country                                                       USA
# awards            Won 6 Oscars. Another 10 wins & 20 nominations.
# ratings_source                            Internet Movie Database
# ratings_value                                              9.0/10
# metascore                                                    85.0
# imdbvotes                                                  856870
# type                                                        movie
# dvd                                           2005-05-24 00:00:00
# boxoffice                                                     NaN
# production                                     Paramount Pictures
# month                                                          12
# day                                                            20
# genre_1                                                     Crime
# genre_2                                                     Drama
# genre_3                                                      None
#
#                                                                 3  \
# imdb_rank                                                       4
# title                                             The Dark Knight
# year                                                         2008
# rated                                                       PG-13
# released                                      2008-07-18 00:00:00
# lengt_min                                                     152
# genre                                        Action, Crime, Drama
# director                                        Christopher Nolan
# writer          Jonathan Nolan (screenplay), Christopher Nolan...
# actors          Christian Bale, Heath Ledger, Aaron Eckhart, M...
# plot            When the menace known as the Joker emerges fro...
# language                                        English, Mandarin
# country                                                   USA, UK
# awards          Won 2 Oscars. Another 151 wins & 153 nominations.
# ratings_source                            Internet Movie Database
# ratings_value                                              9.0/10
# metascore                                                    82.0
# imdbvotes                                                 1802351
# type                                                        movie
# dvd                                           2008-12-09 00:00:00
# boxoffice                                             533316061.0
# production                        Warner Bros. Pictures/Legendary
# month                                                           7
# day                                                            18
# genre_1                                                    Action
# genre_2                                                     Crime
# genre_3                                                     Drama
#
#                                                                 4
# imdb_rank                                                       5
# title                                                12 Angry Men
# year                                                         1957
# rated                                                    APPROVED
# released                                      1957-04-01 00:00:00
# lengt_min                                                      96
# genre                                                Crime, Drama
# director                                             Sidney Lumet
# writer          Reginald Rose (story), Reginald Rose (screenplay)
# actors          Martin Balsam, John Fiedler, Lee J. Cobb, E.G....
# plot            A jury holdout attempts to prevent a miscarria...
# language                                                  English
# country                                                       USA
# awards          Nominated for 3 Oscars. Another 16 wins & 8 no...
# ratings_source                            Internet Movie Database
# ratings_value                                              8.9/10
# metascore                                                    96.0
# imdbvotes                                                  494215
# type                                                        movie
# dvd                                           2001-03-06 00:00:00
# boxoffice                                                     NaN
# production                                   Criterion Collection
# month                                                           4
# day                                                             1
# genre_1                                                     Crime
# genre_2                                                     Drama
# genre_3                                                      None

# %% [markdown]
# ### `director`
#
# Keep only the first one listed.

# %%
df['director']
# Out:
# 0            Frank Darabont
# 1      Francis Ford Coppola
# 2      Francis Ford Coppola
# 3         Christopher Nolan
# 4              Sidney Lumet
#               ...
# 45             Billy Wilder
# 46    Destin Daniel Cretton
# 47             Howard Hawks
# 48              David Lynch
# 49              Danny Boyle
# Name: director, Length: 250, dtype: object

# %% [markdown]
# ### `writer`
#
# Keep only the first one listed!

# %%
df['writer']
# Out:
# 0                Stephen King
# 1                  Mario Puzo
# 2        Francis Ford Coppola
# 3              Jonathan Nolan
# 4               Reginald Rose
#                 ...
# 45         Charles R. Jackson
# 46       Destin Daniel Cretton
# 47            Charles Lederer
# 48    John Roach, Mary Sweeney
# 49              Simon Beaufoy
# Name: writer, Length: 250, dtype: object

# %% [markdown]
# #### `language`
#
# Keep only the first one listed.

# %%
df['language']
# Out:
# 0     English
# 1     English
# 2     English
# 3     English
# 4     English
#        ...
# 45    English
# 46    English
# 47    English
# 48    English
# 49    English
# Name: language, Length: 250, dtype: object

# %% [markdown]
# #### `country`
#
# Keep only the first one listed.

# %%
df['country']
# Out:
# 0        USA
# 1        USA
# 2        USA
# 3        USA
# 4        USA
#        ...
# 45       USA
# 46       USA
# 47       USA
# 48    France
# 49        UK
# Name: country, Length: 250, dtype: object

# %% [markdown]
# #### `ratings_value`
#
# Should be numeric so /10  is not needed.

# %%
df['ratings_value']
# Out:
# 0     9.3
# 1     9.2
# 2     9.0
# 3     9.0
# 4     8.9
#      ...
# 45    8.0
# 46    8.0
# 47    8.0
# 48    8.0
# 49    8.0
# Name: ratings_value, Length: 250, dtype: float64

# %%
list(df['awards'])[0:20]
# Out:
# ['Nominated for 7 Oscars. Another 19 wins & 30 nominations.',
#  'Won 3 Oscars. Another 23 wins & 27 nominations.',
#  'Won 6 Oscars. Another 10 wins & 20 nominations.',
#  'Won 2 Oscars. Another 151 wins & 153 nominations.',
#  'Nominated for 3 Oscars. Another 16 wins & 8 nominations.',
#  'Won 7 Oscars. Another 71 wins & 33 nominations.',
#  'Won 11 Oscars. Another 197 wins & 122 nominations.',
#  'Won 1 Oscar. Another 60 wins & 68 nominations.',
#  'Nominated for 1 Oscar. Another 10 wins & 31 nominations.',
#  'Won 4 Oscars. Another 113 wins & 124 nominations.',
#  'Won 6 Oscars. Another 39 wins & 66 nominations.',
#  'Won 1 Oscar. Another 21 wins & 19 nominations.',
#  'Won 4 Oscars. Another 150 wins & 203 nominations.',
#  'Won 2 Oscars. Another 118 wins & 138 nominations.',
#  'Won 5 Oscars. Another 30 wins & 13 nominations.',
#  'Won 1 Oscar. Another 37 wins & 35 nominations.',
#  'Won 4 Oscars. Another 34 wins & 45 nominations.',
#  'Won 6 Oscars. Another 50 wins & 28 nominations.',
#  'Nominated for 1 Oscar. Another 25 wins & 34 nominations.',
#  'Nominated for 5 Oscars. Another 6 wins & 1 nomination.']

# %% [markdown]
# Extract the number of `oscars`, `oscars nomination`, `nominations`, `otherwins`

# %%
# use regex

# %% [markdown]
# # Long to wide

# %%
# Create a sample DataFrame for long data
df = pd.DataFrame({
    'id': [1, 1, 2, 2, 3, 3],
    'variable': ['A', 'B', 'A', 'C', 'A', 'B'],
    'value': [10, 20, 30, 40, 50, 60]
})

print(df)
# Convert the long data to wide data

wide_data
# Out:
#    id variable  value
# 0   1        A     10
# 1   1        B     20
# 2   2        A     30
# 3   2        C     40
# 4   3        A     50
# 5   3        B     60
# variable     A     B     C
# id
# 1         10.0  20.0   NaN
# 2         30.0   NaN  40.0
# 3         50.0  60.0   NaN

# %%
wide_data.reset_index()
# Out:
# variable  id     A     B     C
# 0          1  10.0  20.0   NaN
# 1          2  30.0   NaN  40.0
# 2          3  50.0  60.0   NaN

# %%
# Create a sample DataFrame for long data
df = pd.DataFrame({
    'id': [1, 1, 2, 2, 3, 3],
    'variable': ['A', 'B', 'A', 'C', 'A', 'B'],
    'value': [10, 20, 30, 40, 50, 60],
    'value2': [101, 202, 330, 440, 650, 60]
})

print(df)
# Convert the long data to wide data
# Out:
#    id variable  value  value2
# 0   1        A     10     101
# 1   1        B     20     202
# 2   2        A     30     330
# 3   2        C     40     440
# 4   3        A     50     650
# 5   3        B     60      60
#          value             value2
# variable     A     B     C      A      B      C
# id
# 1         10.0  20.0   NaN  101.0  202.0    NaN
# 2         30.0   NaN  40.0  330.0    NaN  440.0
# 3         50.0  60.0   NaN  650.0   60.0    NaN

# %% [markdown]
# # Wide to long

# %%
# create data for wide data
df = pd.DataFrame({
    'group': [1, 2, 3],
    'A': [10, 30, 50],
    'B': [20, 40, 60],
    'C': [30, 50, 70]
})

print(df)
# Convert the wide data to long data
# Out:
#    group   A   B   C
# 0      1  10  20  30
# 1      2  30  40  50
# 2      3  50  60  70
#    group variable  value
# 0      1        A     10
# 1      2        A     30
# 2      3        A     50
# 3      1        B     20
# 4      2        B     40
# 5      3        B     60
# 6      1        C     30
# 7      2        C     50
# 8      3        C     70

# %%
# create data for wide data
df = pd.DataFrame({
    'group': [1, 2, 3],
    'A': [10, 30, 50],
    'B': [20, 40, 60],
    'C': [30, 50, 70],
    'D': [301, 510, 720]
})

print(df)
# Convert the wide data to long data
# Out:
#    group   A   B   C    D
# 0      1  10  20  30  301
# 1      2  30  40  50  510
# 2      3  50  60  70  720
#    group variable  value
# 0      1        A     10
# 1      2        A     30
# 2      3        A     50
# 3      1        B     20
# 4      2        B     40
# 5      3        B     60
# 6      1        C     30
# 7      2        C     50
# 8      3        C     70

# %%
# read wine quality data set from web
df = pd.read_csv('https://archive.ics.uci.edu/ml/machine-learning-databases/wine-quality/winequality-white.csv', sep=';')
df.head()

# crate EDA report with plotnine
from plotnine import *

(ggplot(df)
 + aes('quality')
 + geom_bar()
 + theme_minimal()
)

# predict the quality of wine with linear regression
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error
import numpy as np

# split the data into train and test

# fit a linear regression model

# predict the quality of wine

# calculate the RMSE
# Out:
# 0.7334703766710778
