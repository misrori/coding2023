# %% [markdown]
# <a href="https://colab.research.google.com/github/misrori/coding2023/blob/main/session4_to_share.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import plotly.express as px
from plotnine import *

# nycflights13 dataset
flights = pd.read_csv('https://raw.githubusercontent.com/misrori/rdata/main/flights.csv')
airlines = pd.read_csv('https://raw.githubusercontent.com/misrori/rdata/main/airlines.csv')
planes = pd.read_csv('https://raw.githubusercontent.com/misrori/rdata/main/planes.csv')
weather = pd.read_csv('https://raw.githubusercontent.com/misrori/rdata/main/weather.csv')

# Alcohol consumption by country
data = pd.read_csv('https://raw.githubusercontent.com/misrori/rdata/main/DrinksCountry.csv')

# %% [markdown]
# Download the flights dataset into your local environment and read the csv with relative path and with full path, use the tab to autocomplete the path.

# %% [markdown]
# Find the manufacturer (producer) of the plane that flew the most from JFK Airport in January, you can follow these steps:

# %%
# Out:
# 'EMBRAER'

# %% [markdown]
# How many seats the plane with the highest average arrival delay to Miami (MIA) in January had?

# %%
# Out:
# 142

# %% [markdown]
# Filter the flights departing from JFK Airport (origin = 'JFK') in January, calculate the average departure delay for each airline, and create a barchart  plot using Plotly and Plotnie to visualize the results.

# %%
# Out:
#   carrier  dep_delay                      name
# 0      HA  54.387097    Hawaiian Airlines Inc.
# 1      9E  17.086347         Endeavor Air Inc.
# 2      EV  11.914286  ExpressJet Airlines Inc.
# 3      MQ   9.212281                 Envoy Air
# 4      B6   8.538346           JetBlue Airways
# 5      AA   8.187348    American Airlines Inc.
# 6      US   5.210526           US Airways Inc.
# 7      DL   3.875000      Delta Air Lines Inc.
# 8      UA   2.189974     United Air Lines Inc.
# 9      VX   1.063492            Virgin America

# %%
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
# Out:
# <Figure Size: (640 x 480)>

# %% [markdown]
# Find the top 10 destinations from JFK Airport in August

# %%
top_10_destinations
# Out:
#   Destination  Flights
# 0         LAX      979
# 1         SFO      725
# 2         BOS      523
# 3         MCO      493
# 4         SJU      448
# 5         LAS      362
# 6         FLL      336
# 7         BUF      326
# 8         MIA      283
# 9         DCA      281

# %%
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
# Out:
# <Figure Size: (640 x 480)>

# %% [markdown]
# Number of flights by date

# %%
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# # Alcohol consumption

# %%
# Out:
# /usr/local/lib/python3.10/dist-packages/plotnine/stats/stat_bin.py:109: PlotnineWarning:
#
# 'stat_bin()' using 'bins = 7'. Pick better value with 'binwidth'.
# <Figure Size: (640 x 480)>

# %%
# Out:
# <Figure Size: (640 x 480)>

# %%
# Out:
# <Figure Size: (640 x 480)>

# %%
# Out:
# <Figure Size: (640 x 480)>

# %%
# Out:
# <Figure Size: (640 x 480)>

# %%
# Out:
# <Figure Size: (640 x 480)>
